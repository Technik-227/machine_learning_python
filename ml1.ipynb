# %%
1 Python dependencies required for machine learning:
    -> numpy
    -> pandas
    -> scipy
    -> scikit-learn
    -> xgboost
    -> lightgbm
    -> catboost
    -> keras
    -> tensorflow
    -> pytorch
    -> matplotlib
